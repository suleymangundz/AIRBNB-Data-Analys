# %%
import numpy as np
import geopandas as gpd
import pandas as pd
import shapely.geometry as shp
import matplotlib.pyplot as plt
import mapclassify
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import Normalize
import geopandas as gpd

# %%
ev_list = pd.read_csv('listings.csv')
type(ev_list)
ev_list.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
ev_list
# Out:
#                        id                                      listing_url  \
# 0                   25436               https://www.airbnb.com/rooms/25436
# 1                   27271               https://www.airbnb.com/rooms/27271
# 2                  423833              https://www.airbnb.com/rooms/423833
# 3                   28277               https://www.airbnb.com/rooms/28277
# 4                  429200              https://www.airbnb.com/rooms/429200
# ...                   ...                                              ...
# 47513  986773115219367953  https://www.airbnb.com/rooms/986773115219367953
# 47514  986776164830323649  https://www.airbnb.com/rooms/986776164830323649
# 47515  986790278919805377  https://www.airbnb.com/rooms/986790278919805377
# 47516  986796471490590812  https://www.airbnb.com/rooms/986796471490590812
# 47517  986798249484186143  https://www.airbnb.com/rooms/986798249484186143
#
#             scrape_id last_scraped           source  \
# 0      20230924144329   2023-09-24      city scrape
# 1      20230924144329   2023-09-24      city scrape
# 2      20230924144329   2023-09-24  previous scrape
# 3      20230924144329   2023-09-25      city scrape
# 4      20230924144329   2023-09-24      city scrape
# ...               ...          ...              ...
# 47513  20230924144329   2023-09-25      city scrape
# 47514  20230924144329   2023-09-24      city scrape
# 47515  20230924144329   2023-09-25      city scrape
# 47516  20230924144329   2023-09-24      city scrape
# 47517  20230924144329   2023-09-25      city scrape
#
#                                                     name  \
# 0      Rental unit in Beşiktaş/ bebek · 2 bedrooms · ...
# 1      Rental unit in Istanbul Province · ★5.0 · 1 be...
# 2      Rental unit in Istanbul · 1 bedroom · 4 beds ·...
# 3      Serviced apartment in Istanbul · ★5.0 · 1 bedr...
# 4      Loft in Istanbul Galata Beyoglu Tophane  · 2 b...
# ...                                                  ...
# 47513  Rental unit in Şişli · ★New · 1 bedroom · 1 be...
# 47514  Rental unit in Kadıköy · ★New · 3 bedrooms · 4...
# 47515  Rental unit in Kadıköy · ★New · 2 bedrooms · 2...
# 47516  Rental unit in Beyoğlu · ★New · 1 bedroom · 1 ...
# 47517  Rental unit in Beşiktaş · ★New · 2 bedrooms · ...
#
#                                              description  \
# 0      Evimiz Bebek Koru nun içinde . Şehrin  içinde ...
# 1      This is a  nicely decorated apartment in an an...
# 2      <b>The space</b><br />Hi,the house is central ...
# 3      <b>The space</b><br />The first advantage to s...
# 4      <b>The space</b><br />in the heart of İstanbul...
# ...                                                  ...
# 47513  Bu huzurlu konaklama yerinde ailece dinlenebil...
# 47514  Welcome to Moda district, the most modern face...
# 47515  central location apartment in kadikoy /istanbu...
# 47516  Welcome to a stay at an apartment in a newly r...
# 47517  İstanbul, Nişantaşı, Akaretler, Beşiktaş semti...
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 1      Cihangir is one of Istanbul's cosmopolitan sub...
# 2      The neigborhood is safe. It's central anything...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 47513                                                NaN
# 47514                                                NaN
# 47515                                                NaN
# 47516                                                NaN
# 47517  Beşiktaş İstanbul'un ünlü semtlerinden biridir...
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/b64c3ef0-2256...     105823  ...
# 1      https://a0.muscache.com/pictures/2f9cfc85-8370...     117026  ...
# 2      https://a0.muscache.com/pictures/6611176/3cd15...    2081426  ...
# 3      https://a0.muscache.com/pictures/miso/Hosting-...     121607  ...
# 4      https://a0.muscache.com/pictures/5082924/46704...     182639  ...
# ...                                                  ...        ...  ...
# 47513  https://a0.muscache.com/pictures/miso/Hosting-...  538515852  ...
# 47514  https://a0.muscache.com/pictures/miso/Hosting-...   68969284  ...
# 47515  https://a0.muscache.com/pictures/hosting/Hosti...  286838307  ...
# 47516  https://a0.muscache.com/pictures/miso/Hosting-...   96460850  ...
# 47517  https://a0.muscache.com/pictures/miso/Hosting-...   20030201  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                             NaN                    NaN                 NaN
# 1                             5.0                    5.0                5.00
# 2                             5.0                    5.0                4.00
# 3                             5.0                    5.0                4.75
# 4                             2.0                    3.0                1.00
# ...                           ...                    ...                 ...
# 47513                         NaN                    NaN                 NaN
# 47514                         NaN                    NaN                 NaN
# 47515                         NaN                    NaN                 NaN
# 47516                         NaN                    NaN                 NaN
# 47517                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN                f                              1
# 1         NaN                f                              1
# 2         NaN                f                              1
# 3         NaN                f                             21
# 4         NaN                f                              6
# ...       ...              ...                            ...
# 47513     NaN                f                              1
# 47514     NaN                f                              1
# 47515     NaN                t                              1
# 47516     NaN                f                            240
# 47517     NaN                t                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               1
# 2                                               0
# 3                                              21
# 4                                               6
# ...                                           ...
# 47513                                           1
# 47514                                           1
# 47515                                           1
# 47516                                         240
# 47517                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                1
# 3                                                0
# 4                                                0
# ...                                            ...
# 47513                                            0
# 47514                                            0
# 47515                                            0
# 47516                                            0
# 47517                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0               NaN
# 1                                               0              0.04
# 2                                               0              0.01
# 3                                               0              0.28
# 4                                               0              0.01
# ...                                           ...               ...
# 47513                                           0               NaN
# 47514                                           0               NaN
# 47515                                           0               NaN
# 47516                                           0               NaN
# 47517                                           0               NaN
#
# [47518 rows x 75 columns]

# %%
columns_to_drop = ['listing_url','scrape_id','last_scraped','source','picture_url','host_id','host_url','host_since','host_response_time','host_is_superhost', 'host_thumbnail_url', 'host_picture_url','host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified','minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm','availability_30', 'availability_60', 'availability_90',
       'availability_365', 'calendar_last_scraped', 'number_of_reviews',
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'license', 'instant_bookable',
       'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms']
ev_list = ev_list.drop(columns = columns_to_drop)

# %%
columns_to_process = ['description', 'name','host_name','host_location', 'host_about','neighbourhood',
       'neighbourhood_cleansed', 'neighbourhood_group_cleansed','host_neighbourhood','price']
ev_list[columns_to_process] = ev_list[columns_to_process].astype(str).replace('[^\w\s]', '', regex=True)
ev_list
# Out:
#                        id                                               name  \
# 0                   25436  Rental unit in Beşiktaş bebek  2 bedrooms  4 b...
# 1                   27271  Rental unit in Istanbul Province  50  1 bedroo...
# 2                  423833  Rental unit in Istanbul  1 bedroom  4 beds  1 ...
# 3                   28277  Serviced apartment in Istanbul  50  1 bedroom ...
# 4                  429200  Loft in Istanbul Galata Beyoglu Tophane   2 be...
# ...                   ...                                                ...
# 47513  986773115219367953  Rental unit in Şişli  New  1 bedroom  1 bed  1...
# 47514  986776164830323649  Rental unit in Kadıköy  New  3 bedrooms  4 bed...
# 47515  986790278919805377  Rental unit in Kadıköy  New  2 bedrooms  2 bed...
# 47516  986796471490590812  Rental unit in Beyoğlu  New  1 bedroom  1 bed ...
# 47517  986798249484186143  Rental unit in Beşiktaş  New  2 bedrooms  3 be...
#
#                                              description  \
# 0      Evimiz Bebek Koru nun içinde  Şehrin  içinde k...
# 1      This is a  nicely decorated apartment in an an...
# 2      bThe spacebbr Hithe house is central and in a ...
# 3      bThe spacebbr The first advantage to stay in o...
# 4      bThe spacebbr in the heart of İstanbul in the ...
# ...                                                  ...
# 47513  Bu huzurlu konaklama yerinde ailece dinlenebil...
# 47514  Welcome to Moda district the most modern face ...
# 47515  central location apartment in kadikoy istanbul...
# 47516  Welcome to a stay at an apartment in a newly r...
# 47517  İstanbul Nişantaşı Akaretler Beşiktaş semtinde...
#
#                                    neighborhood_overview   host_name  \
# 0                                                    NaN       Yesim
# 1      Cihangir is one of Istanbul's cosmopolitan sub...       Mutlu
# 2      The neigborhood is safe. It's central anything...       Sanem
# 3                                                    NaN        Alen
# 4                                                    NaN  Mehmet Ali
# ...                                                  ...         ...
# 47513                                                NaN      Cumali
# 47514                                                NaN      Serhan
# 47515                                                NaN      Sherif
# 47516                                                NaN      Tevfik
# 47517  Beşiktaş İstanbul'un ünlü semtlerinden biridir...      Fadile
#
#          host_location                                         host_about  \
# 0      İstanbul Turkey  Merhabalar   Kuş sesi  akan su sesi ile uyanac...
# 1      Istanbul Turkey   I am a tourist guide and diving instructor I ...
# 2      Istanbul Turkey  Hi\r\nI am expecting guests I think i am frien...
# 3      İstanbul Turkey  I have been working as a property manager in İ...
# 4      Istanbul Turkey  I am experienced in hosting people from all ov...
# ...                ...                                                ...
# 47513              nan                                                nan
# 47514   Fethiye Turkey                                   Traveller couple
# 47515              nan                                                nan
# 47516     Izmir Turkey                                                nan
# 47517  İstanbul Turkey  My name is Fadile welcome to my Airbnb home an...
#
#       host_response_rate host_acceptance_rate host_neighbourhood  ...  \
# 0                    NaN                  NaN           Beşiktaş  ...
# 1                     0%                  50%           Cihangir  ...
# 2                    NaN                  NaN              Şişli  ...
# 3                   100%                  78%              Şişli  ...
# 4                    NaN                 100%            Karaköy  ...
# ...                  ...                  ...                ...  ...
# 47513                NaN                  NaN                nan  ...
# 47514               100%                  NaN                nan  ...
# 47515               100%                 100%                nan  ...
# 47516               100%                  90%                nan  ...
# 47517               100%                 100%                nan  ...
#
#       bathrooms_text bedrooms beds  \
# 0             1 bath      2.0  4.0
# 1             1 bath      1.0  1.0
# 2             1 bath      NaN  4.0
# 3             1 bath      1.0  2.0
# 4             1 bath      2.0  2.0
# ...              ...      ...  ...
# 47513         1 bath      1.0  1.0
# 47514        2 baths      3.0  4.0
# 47515         1 bath      2.0  2.0
# 47516         1 bath      1.0  1.0
# 47517         1 bath      2.0  3.0
#
#                                                amenities   price  \
# 0      ["Cleaning products", "Hot water kettle", "Saf...  289400
# 1      ["Cleaning products", "Hot water kettle", "Saf...  144700
# 2      ["Heating", "Wifi", "Dryer", "Hot tub", "Washe...  115700
# 3      ["Washer", "Bathtub", "Heating", "Patio or bal...  257500
# 4      ["Cleaning products", "Hot water kettle", "Fre...  228600
# ...                                                  ...     ...
# 47513                ["Washer", "Kitchen", "TV", "Wifi"]  115700
# 47514  ["Cleaning products", "Hot water kettle", "Mos...  250000
# 47515  ["Washer", "Dedicated workspace", "Wifi", "Sel...  118400
# 47516  ["Cleaning products", "Hot water kettle", "Toa...  205800
# 47517  ["Cleaning products", "Hot water kettle", "Eth...  162000
#
#       minimum_nights maximum_nights  calendar_updated  has_availability  \
# 0                  3           1125               NaN                 t
# 1                 10             90               NaN                 t
# 2                  2             60               NaN                 f
# 3                 10            360               NaN                 t
# 4                  5           1125               NaN                 t
# ...              ...            ...               ...               ...
# 47513              1            365               NaN                 t
# 47514              5             60               NaN                 t
# 47515              3             90               NaN                 t
# 47516              2            365               NaN                 t
# 47517              1            365               NaN                 t
#
#       reviews_per_month
# 0                   NaN
# 1                  0.04
# 2                  0.01
# 3                  0.28
# 4                  0.01
# ...                 ...
# 47513               NaN
# 47514               NaN
# 47515               NaN
# 47516               NaN
# 47517               NaN
#
# [47518 rows x 29 columns]

# %%
ev_list['geometry'] = ev_list[['longitude', 'latitude']].apply(shp.Point, axis=1)
ev_list= gpd.GeoDataFrame(ev_list)
type(ev_list)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
ev_list.crs = {'init':'epsg:4329'}
ev_list.crs
# Out:
# C:\Users\YPN-1067\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <Geographic 3D CRS: +init=epsg:4329 +type=crs>
# Name: WGS 84 (3D)
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# - h[up]: Ellipsoidal height (metre)
# Area of Use:
# - name: World: Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Anguilla, Antarctica, Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belgium, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Bonaire, Saint Eustasius and Saba, Bosnia and Herzegovina, Botswana, Bouvet Island, Brazil, British Indian Ocean Territory, British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Comoros, Congo, Cook Islands, Costa Rica, Côte d'Ivoire (Ivory Coast), Croatia, Cuba, Cur
traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ev_list.to_file("ev_list.csv", driver="csv")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\geodataframe.py:1264, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1173 """Write the ``GeoDataFrame`` to a file.
#    1174
#    1175 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1260
#    1261 """
#    1262 from geopandas.io.file import _to_file
# -> 1264 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\file.py:608, in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     605     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     607 if engine == "fiona":
# --> 608     _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     609 elif engine == "pyogrio":
#     610     _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\io\file.py:634, in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     632 elif crs:
#     633     crs_wkt = crs.to_wkt("WKT1_GDAL")
# --> 634 with fiona.open(
#     635     filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     636 ) as colxn:
#     637     colxn.writerecords(df.iterfeatures())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fiona\__init__.py:316, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     305     colxn = Collection(
#     306         path,
#     307         mode,
#    (...)
#     313         **kwargs
#     314     )
#     315 elif mode == "w":
# --> 316     colxn = Collection(
#     317         path,
#     318         mode,
#     319         crs=crs,
#     320         driver=driver,
#     321         schema=schema,
#     322         encoding=encoding,
#     323         layer=layer,
#     324         enabled_drivers=enabled_drivers,
#     325         crs_wkt=crs_wkt,
#     326         allow_unsupported_drivers=allow_unsupported_drivers,
#     327         **kwargs
#     328     )
#     329 else:
#     330     raise ValueError("mode string must be one of {'r', 'w', 'a'}")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\fiona\collection.py:211, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     209 if not allow_unsupported_drivers:
#     210     if driver not in supported_drivers:
# --> 211         raise DriverError("unsupported driver: %r" % driver)
#     212     if self.mode not in supported_drivers[driver]:
#     213         raise DriverError("unsupported mode: %r" % self.mode)
#
# DriverError: unsupported driver: 'csv'

# %%
ax = ist_ilce_list.plot(figsize=(15,15), alpha = 0.3, edgecolor ='gray')
ev_list.plot(ax=ax,color='yellow', marker='o', markersize=15)
# Out:
# <Axes: >

# %%
ax = ist_ilce_list.plot(figsize=(15,15), alpha = 0.3, edgecolor ='gray')
ev_list.sort_values('price').plot('price',ax=ax,c='plasma', marker='o', markersize=15)
# Out:
# <Axes: >

# %%
evler2 = ev_list.dropna(subset=['description'])
evler2.loc[evler2['description'].str.contains('manzara|Manzara|MANZARA', regex=True)]

# %%
evler2 = ev_list.dropna(subset=['description'])
evler2.loc[evler2['description'].str.contains('deniz|DENIZ|Deniz', regex=True)]

# %%
ax = ist_ilce_list.plot(figsize=(15,15), alpha = 0.3, edgecolor ='gray')
ev_list.loc[ev_list['description'].str.contains('deniz|DENIZ|Deniz')].plot(ax=ax, c='darkblue', marker='o', markersize= 15)

# %%
ax = ist_ilce_list.plot(figsize=(15,15), alpha = 0.3, edgecolor ='gray')
ev_list.loc[ev_list['description'].str.contains('manzara|Manzara|MANZARA')].plot(ax=ax, color='orange', marker='o', markersize= 15)

# %%
evler2 = ev_list.dropna(subset=['description'])
evler2.loc[evler2['description'].str.contains('metrobus|Metrobus|METROBUS', regex=True)]

# %%
ax = ist_ilce_list.plot(figsize=(15,15), alpha = 0.3, edgecolor ='gray')
ev_list.loc[ev_list['description'].str.contains('metrobus|Metrobus|METROBUS')].plot(ax=ax, color='yellow', marker='o', markersize= 15)

# %%
ev_ilce_list = gpd.sjoin(ev_list, ist_ilce_list, op='within', how='left')
ev_ilce_list
# Out:
# C:\Users\YPN-1067\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# C:\Users\YPN-1067\AppData\Local\Temp\ipykernel_10552\3491363614.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4329 +type=crs
# Right CRS: EPSG:4326
#
#   ev_ilce_list = gpd.sjoin(ev_list, ist_ilce_list, op='within', how='left')
#                        id                                               name  \
# 0                   25436  Rental unit in Beşiktaş bebek  2 bedrooms  4 b...
# 1                   27271  Rental unit in Istanbul Province  50  1 bedroo...
# 2                  423833  Rental unit in Istanbul  1 bedroom  4 beds  1 ...
# 3                   28277  Serviced apartment in Istanbul  50  1 bedroom ...
# 4                  429200  Loft in Istanbul Galata Beyoglu Tophane   2 be...
# ...                   ...                                                ...
# 47513  986773115219367953  Rental unit in Şişli  New  1 bedroom  1 bed  1...
# 47514  986776164830323649  Rental unit in Kadıköy  New  3 bedrooms  4 bed...
# 47515  986790278919805377  Rental unit in Kadıköy  New  2 bedrooms  2 bed...
# 47516  986796471490590812  Rental unit in Beyoğlu  New  1 bedroom  1 bed ...
# 47517  986798249484186143  Rental unit in Beşiktaş  New  2 bedrooms  3 be...
#
#                                              description  \
# 0      Evimiz Bebek Koru nun içinde  Şehrin  içinde k...
# 1      This is a  nicely decorated apartment in an an...
# 2      bThe spacebbr Hithe house is central and in a ...
# 3      bThe spacebbr The first advantage to stay in o...
# 4      bThe spacebbr in the heart of İstanbul in the ...
# ...                                                  ...
# 47513  Bu huzurlu konaklama yerinde ailece dinlenebil...
# 47514  Welcome to Moda district the most modern face ...
# 47515  central location apartment in kadikoy istanbul...
# 47516  Welcome to a stay at an apartment in a newly r...
# 47517  İstanbul Nişantaşı Akaretler Beşiktaş semtinde...
#
#                                    neighborhood_overview   host_name  \
# 0                                                    NaN       Yesim
# 1      Cihangir is one of Istanbul's cosmopolitan sub...       Mutlu
# 2      The neigborhood is safe. It's central anything...       Sanem
# 3                                                    NaN        Alen
# 4                                                    NaN  Mehmet Ali
# ...                                                  ...         ...
# 47513                                                NaN      Cumali
# 47514                                                NaN      Serhan
# 47515                                                NaN      Sherif
# 47516                                                NaN      Tevfik
# 47517  Beşiktaş İstanbul'un ünlü semtlerinden biridir...      Fadile
#
#          host_location                                         host_about  \
# 0      İstanbul Turkey  Merhabalar   Kuş sesi  akan su sesi ile uyanac...
# 1      Istanbul Turkey   I am a tourist guide and diving instructor I ...
# 2      Istanbul Turkey  Hi\r\nI am expecting guests I think i am frien...
# 3      İstanbul Turkey  I have been working as a property manager in İ...
# 4      Istanbul Turkey  I am experienced in hosting people from all ov...
# ...                ...                                                ...
# 47513              nan                                                nan
# 47514   Fethiye Turkey                                   Traveller couple
# 47515              nan                                                nan
# 47516     Izmir Turkey                                                nan
# 47517  İstanbul Turkey  My name is Fadile welcome to my Airbnb home an...
#
#       host_response_rate host_acceptance_rate host_neighbourhood  ...   price  \
# 0                    NaN                  NaN           Beşiktaş  ...  289400
# 1                     0%                  50%           Cihangir  ...  144700
# 2                    NaN                  NaN              Şişli  ...  115700
# 3                   100%                  78%              Şişli  ...  257500
# 4                    NaN                 100%            Karaköy  ...  228600
# ...                  ...                  ...                ...  ...     ...
# 47513                NaN                  NaN                nan  ...  115700
# 47514               100%                  NaN                nan  ...  250000
# 47515               100%                 100%                nan  ...  118400
# 47516               100%                  90%                nan  ...  205800
# 47517               100%                 100%                nan  ...  162000
#
#       minimum_nights maximum_nights  calendar_updated  has_availability  \
# 0                  3           1125               NaN                 t
# 1                 10             90               NaN                 t
# 2                  2             60               NaN                 f
# 3                 10            360               NaN                 t
# 4                  5           1125               NaN                 t
# ...              ...            ...               ...               ...
# 47513              1            365               NaN                 t
# 47514              5             60               NaN                 t
# 47515              3             90               NaN                 t
# 47516              2            365               NaN                 t
# 47517              1            365               NaN                 t
#
#       reviews_per_month                   geometry  index_right  \
# 0                   NaN  POINT (29.03863 41.07883)         23.0
# 1                  0.04  POINT (28.98153 41.03254)         22.0
# 2                  0.01  POINT (28.99176 41.05317)         25.0
# 3                  0.28  POINT (28.98402 41.04672)         25.0
# 4                  0.01  POINT (28.97751 41.02734)         22.0
# ...                 ...                        ...          ...
# 47513               NaN  POINT (28.97717 41.05536)         25.0
# 47514               NaN  POINT (29.02227 40.98042)         29.0
# 47515               NaN  POINT (29.02712 40.99471)         29.0
# 47516               NaN  POINT (28.97322 41.02506)         22.0
# 47517               NaN  POINT (29.00039 41.04694)         23.0
#
#        neighbourhood_right neighbourhood_group
# 0                 Besiktas                None
# 1                  Beyoglu                None
# 2                    Sisli                None
# 3                    Sisli                None
# 4                  Beyoglu                None
# ...                    ...                 ...
# 47513                Sisli                None
# 47514              Kadikoy                None
# 47515              Kadikoy                None
# 47516              Beyoglu                None
# 47517             Besiktas                None
#
# [47519 rows x 33 columns]

# %%
ev_ilce_list['price'] = ev_ilce_list['price'].astype(str)
ev_ilce_list['price'] = ev_ilce_list['price'].astype(float)

İlce_ort_price = (ev_ilce_list.groupby(['neighbourhood_right'])['price'].mean()/10000).round(4)
İlce_ort_price =İlce_ort_price.sort_values(ascending=False)
İlce_ort_price
# Out:
# neighbourhood_right
# Cekmekoy         55.0242
# Buyukcekmece     50.3611
# Beykoz           48.7533
# Besiktas         47.8311
# Bagcilar         46.3504
# Silivri          45.1707
# Eyup             41.5774
# Sariyer          37.3411
# Sile             33.6036
# Sancaktepe       32.3914
# Beyoglu          29.8335
# Adalar           29.5550
# Fatih            28.3430
# Catalca          27.9050
# Sisli            27.6827
# Gaziosmanpasa    27.5824
# Basaksehir       25.3187
# Bakirkoy         24.4099
# Kucukcekmece     24.2056
# Beylikduzu       23.9007
# Bahcelievler     23.6877
# Pendik           21.2666
# Uskudar          20.2632
# Zeytinburnu      20.2181
# Arnavutkoy       19.3317
# Atasehir         18.7360
# Bayrampasa       18.0977
# Tuzla            17.7117
# Kadikoy          17.6090
# Umraniye         17.5556
# Kagithane        16.5478
# Kartal           16.5080
# Esenyurt         16.1381
# Sultangazi       14.7788
# Maltepe          13.5046
# Avcilar          12.7812
# Esenler          12.7681
# Gungoren         12.4439
# Sultanbeyli      10.5531
# Name: price, dtype: float64

# %%
ev_ilce_list['toplam ev sayısı']  =1
ev_ilce_list
toplam_ev_sayısı = ev_ilce_list.groupby(['neighbourhood_right']).count()['toplam ev sayısı']
toplam_ev_sayısı.sort_values(ascending=False)
toplam_ev_sayısı = toplam_ev_sayısı.to_frame()

# %%
toplam_ev_sayısı.plot(kind='bar', figsize=(15,15))
plt.title('İlçelerdeki Airbnb Daire Sayıları', fontdict={'fontname': 'Comic Sans MS', 'fontsize':20})
# Out:
# Text(0.5, 1.0, 'İlçelerdeki Airbnb Daire Sayıları')

# %%
toplam_ev_sayısı.plot(kind='pie', figsize=(15,15))
plt.title('İlçelerdeki Airbnb Daire Sayıları', fontdict={'fontname': 'Comic Sans MS', 'fontsize':20})

# %%
ev_ilce_price_merge = ist_ilce_list.merge(İlce_ort_price,left_on='neighbourhood', right_on='neighbourhood_right')
ev_ilce_ort_top_list = ev_ilce_price_merge.merge(toplam_ev_sayısı,left_on='neighbourhood', right_on='neighbourhood_right')
ev_ilce_ort_top_list
# Out:
#     neighbourhood neighbourhood_group  \
# 0            Sile                None
# 1         Catalca                None
# 2            Eyup                None
# 3         Sariyer                None
# 4      Arnavutkoy                None
# 5         Silivri                None
# 6       Kagithane                None
# 7    Buyukcekmece                None
# 8        Esenyurt                None
# 9      Beylikduzu                None
# 10        Avcilar                None
# 11   Bahcelievler                None
# 12       Bakirkoy                None
# 13   Kucukcekmece                None
# 14     Basaksehir                None
# 15       Bagcilar                None
# 16     Sultangazi                None
# 17       Gungoren                None
# 18        Esenler                None
# 19     Bayrampasa                None
# 20    Zeytinburnu                None
# 21          Fatih                None
# 22        Beyoglu                None
# 23       Besiktas                None
# 24        Maltepe                None
# 25          Sisli                None
# 26        Uskudar                None
# 27         Beykoz                None
# 28         Pendik                None
# 29        Kadikoy                None
# 30       Atasehir                None
# 31       Umraniye                None
# 32     Sancaktepe                None
# 33    Sultanbeyli                None
# 34         Kartal                None
# 35          Tuzla                None
# 36       Cekmekoy                None
# 37         Adalar                None
# 38  Gaziosmanpasa                None
#
#                                              geometry    price  \
# 3                569
# 4                278
# 5                150
# 6               1499
# 7                370
# 8               2000
# 9                454
# 10               635
# 11               777
# 12               592
# 13               540
# 14               630
# 15               967
# 16                51
# 17               120
# 18                89
# 19               113
# 20               350
# 21              4551
# 22             10089
# 23              2938
# 24               956
# 25              7028
# 26              1564
# 27               254
# 28               509
# 29              5052
# 30               951
# 31               587
# 32                87
# 33                42
# 34               463
# 35               223
# 36               154
# 37               491
# 38               191

# %%
ax = ev_ilce_ort_top_list.plot(figsize=(15,15), column='price', scheme='fisher_jenks', k=10, legend=True, cmap='YlGn', edgecolor='black')
ax.set_title("İlçelere Göre Hesaplanmış Ortalama Airbnb Günlük Kiralama Ücretleri - (TL)")
plt.savefig('istanbul-airbnb-listelenmis-ilce-bazli-map.png', dpi=300)

# %%
ax = ev_ilce_ort_top_list.plot(figsize=(15,15), column='price', scheme='fisher_jenks', k=7, legend=True, cmap='YlGn', edgecolor='black')
ax.set_title("İlçelere Göre Hesaplanmış Ortalama Airbnb Günlük Kiralama Ücretleri - (TL)")
plt.savefig('istanbul-airbnb-listelenmis-ilce-bazli-map.png', dpi=300)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,15))  # figür nesnesi ve tek bir eksen
ev_ilce_ort_top_list.plot(column='price', ax=ax, legend=True, legend_kwds={'label': 'Daire Günlük Fiyatları', 'orientation': 'horizontal'})
formatter = ScalarFormatter(useOffset=False, useMathText=True)
formatter.set_scientific(False)
formatter.set_powerlimits((-1, 2))  # İsteğe bağlı: Sayının bilimsel gösterilme limitleri

ax.yaxis.set_major_formatter(formatter)

plt.show()

# %%
host_location= ev_list['host_location']
ev_ilce_list['ev sahibi lokasyonu']  =1
host_location = ev_ilce_list.groupby(['host_location']).count()['ev sahibi lokasyonu']
host_location = host_location.to_frame()
host_location
# Out:
#                                 ev sahibi lokasyonu
# host_location
# Aachen Germany                                    1
# Abidjan Côte dIvoire                              1
# Abu Dhabi United Arab Emirates                    2
# Abu Halifa Kuwait                                 1
# Abuja Nigeria                                     2
# ...                                             ...
# İzmit Turkey                                      7
# Şamlar Turkey                                     1
# Şanlıurfa Turkey                                  1
# Şile Turkey                                      58
# Şişli Turkey                                      1
#
# [527 rows x 1 columns]

# %%
y = ev_list['Price']
df_train= df_train.drop(['Price'], axis=1)

x_train, x_test, y_train, y_test = train_test_split(df_train, y, test_size=0.3, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 y = ev_list['Price']
#       2 df_train= df_train.drop(['Price'], axis=1)
#       4 x_train, x_test, y_train, y_test = train_test_split(df_train, y, test_size=0.3, random_state=0)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\geopandas\geodataframe.py:1474, in GeoDataFrame.__getitem__(self, key)
#    1468 def __getitem__(self, key):
#    1469     """
#    1470     If the result is a column containing only 'geometry', return a
#    1471     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1472     return a GeoDataFrame.
#    1473     """
# -> 1474     result = super().__getitem__(key)
#    1475     # Custom logic to avoid waiting for pandas GH51895
#    1476     # result is not geometry dtype for multi-indexes
#    1477     if (
#    1478         pd.api.types.is_scalar(key)
#    1479         and key == ""
#    (...)
#    1482         and not is_geometry_type(result)
#    1483     ):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Price'
