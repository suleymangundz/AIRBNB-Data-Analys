# %% [markdown]
# <a href="https://colab.research.google.com/github/suleymangundz/AIRBNB-Data-Analys/blob/main/AIRBNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import geopandas as gpd
import pandas as pd
import shapely.geometry as shp
import matplotlib.pyplot as plt
import mapclassify
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import Normalize
import geopandas as gpd
from google.colab import drive

# %%
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/AIRBNB Data Analys/listings.csv'
ev_list = pd.read_csv(file_path)
type(ev_list)
ev_list.columns
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
columns_to_drop = ['listing_url','scrape_id','last_scraped','source','picture_url','host_id','host_url','host_since','host_response_time','host_is_superhost', 'host_thumbnail_url', 'host_picture_url','host_listings_count',
       'host_total_listings_count', 'host_verifications',
       'host_has_profile_pic', 'host_identity_verified','minimum_minimum_nights',
       'maximum_minimum_nights', 'minimum_maximum_nights',
       'maximum_maximum_nights', 'minimum_nights_avg_ntm',
       'maximum_nights_avg_ntm','availability_30', 'availability_60', 'availability_90',
       'availability_365', 'calendar_last_scraped', 'number_of_reviews',
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'license', 'instant_bookable',
       'calculated_host_listings_count',
       'calculated_host_listings_count_entire_homes',
       'calculated_host_listings_count_private_rooms',
       'calculated_host_listings_count_shared_rooms']
ev_list = ev_list.drop(columns = columns_to_drop)

# %%
columns_to_process = ['description', 'name','host_name','host_location', 'host_about','neighbourhood',
       'neighbourhood_cleansed', 'neighbourhood_group_cleansed','host_neighbourhood','price']
ev_list[columns_to_process] = ev_list[columns_to_process].astype(str).replace('[^\w\s]', '', regex=True)
ev_list
# Out:
#                        id                                               name  \
# 0                   25436  Rental unit in Beşiktaş bebek  2 bedrooms  4 b...
# 1                   27271  Rental unit in Istanbul Province  50  1 bedroo...
# 2                  423833  Rental unit in Istanbul  1 bedroom  4 beds  1 ...
# 3                   28277  Serviced apartment in Istanbul  50  1 bedroom ...
# 4                  429200  Loft in Istanbul Galata Beyoglu Tophane   2 be...
# ...                   ...                                                ...
# 47513  986773115219367953  Rental unit in Şişli  New  1 bedroom  1 bed  1...
# 47514  986776164830323649  Rental unit in Kadıköy  New  3 bedrooms  4 bed...
# 47515  986790278919805377  Rental unit in Kadıköy  New  2 bedrooms  2 bed...
# 47516  986796471490590812  Rental unit in Beyoğlu  New  1 bedroom  1 bed ...
# 47517  986798249484186143  Rental unit in Beşiktaş  New  2 bedrooms  3 be...
#
# ...

# %%
ev_list['geometry'] = ev_list[['longitude', 'latitude']].apply(shp.Point, axis=1)
ev_list= gpd.GeoDataFrame(ev_list)
type(ev_list)
ev_list.crs = {'init':'epsg:4329'}
ev_list.crs
# Out:
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# <Geographic 3D CRS: +init=epsg:4329 +type=crs>
# Name: WGS 84 (3D)
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# - h[up]: Ellipsoidal height (metre)
# Area of Use:
# ...

# %%
ist_ilce_list = gpd.read_file('ist_neighbourhoods.geojson')
ist_ilce_list
# Out:
# ERROR:fiona._env:ist_neighbourhoods.geojson: No such file or directory
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ist_neighbourhoods.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-15-bf2bdc67e3db> in <cell line: 1>()
# ----> 1 ist_ilce_list = gpd.read_file('ist_neighbourhoods.geojson')
#       2 ist_ilce_list
#
# /usr/local/lib/python3.10/dist-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     279             path_or_bytes = filename
#     280
# --> 281         return _read_file_fiona(
# ...
